# %% [markdown]
# # Lab 3: Tables
#
# Welcome to lab 3!  This week, we'll learn about *tables*, which let us work with multiple arrays of data about the same things.  Tables are described in [Chapter 5](http://www.inferentialthinking.com/chapters/05/tables.html) of the text.
#
# First, set up the tests and imports by running the cell below.

# %%
import numpy as np
from datascience import *
import pandas as pd

# These lines load the tests.

#from client.api.notebook import Notebook
#ok = Notebook('lab03.ok')
#_ = ok.auth(inline=True)

# %% [markdown]
# ## 1. Introduction
#
# For a collection of things in the world, an array is useful for describing a single attribute of each thing. For example, among the collection of US States, an array could describe the land area of each. Tables extend this idea by describing multiple attributes for each element of a collection.
#
# In most data science applications, we have data about many entities, but we also have several kinds of data about each entity.
#
# For example, in the cell below we have two arrays. The first one contains the world population in each year (as [estimated](http://www.census.gov/population/international/data/worldpop/table_population.php) by the US Census Bureau), and the second contains the years themselves (in order, so the first elements in the population and the years arrays correspond).

# %%
population_amounts = Table.read_table("world_population.csv").column("Population")
years = np.arange(1950, 2015+1)
print("Population column:", population_amounts)
print("Years column:", years)
# Out:
# Population column: [2557628654 2594939877 2636772306 2682053389 2730228104 2782098943
#  2835299673 2891349717 2948137248 3000716593 3043001508 3083966929
#  3140093217 3209827882 3281201306 3350425793 3420677923 3490333715
#  3562313822 3637159050 3712697742 3790326948 3866568653 3942096442
#  4016608813 4089083233 4160185010 4232084578 4304105753 4379013942
#  4451362735 4534410125 4614566561 4695736743 4774569391 4856462699
#  4940571232 5027200492 5114557167 5201440110 5288955934 5371585922
#  5456136278 5538268316 5618682132 5699202985 5779440593 5857972543
#  5935213248 6012074922 6088571383 6165219247 6242016348 6318590956
#  6395699509 6473044732 6551263534 6629913759 6709049780 6788214394
#  6866332358 6944055583 7022349283 7101027895 7178722893 7256490011]
# Years column: [1950 1951 1952 1953 1954 1955 1956 1957 1958 1959 1960 1961 1962 1963 1964
#  1965 1966 1967 1968 1969 1970 1971 1972 1973 1974 1975 1976 1977 1978 1979
#  1980 1981 1982 1983 1984 1985 1986 1987 1988 1989 1990 1991 1992 1993 1994
#  1995 1996 1997 1998 1999 2000 2001 2002 2003 2004 2005 2006 2007 2008 2009
#  2010 2011 2012 2013 2014 2015]

# %% [markdown]
# Suppose we want to answer this question:
#
# > When did world population cross 6 billion?
#
# You could technically answer this question just from staring at the arrays, but it's a bit convoluted, since you would have to count the position where the population first crossed 6 billion, then find the corresponding element in the years array. In cases like these, it might be easier to put the data into a *`Table`*, a 2-dimensional type of dataset.
#
# The expression below:
#
# - creates an empty table using the expression `Table()`,
# - adds two columns by calling `with_columns` with four arguments,
# - assignes the result to the name `population`, and finally
# - evaluates `population` so that we can see the table.
#
# The strings `"Year"` and `"Population"` are column labels that we have chosen. Ther names `population_amounts` and `years` were assigned above to two arrays of the same length. The function `with_columns` (you can find the documentation [here](http://data8.org/datascience/tables.html)) takes in alternating strings (to represent column labels) and arrays (representing the data in those columns), which are all separated by commas.

# %%
# population = Table().with_columns(
#     "Population", population_amounts,
#     "Year", years
# )
population = pd.DataFrame()
population['Population'] = population_amounts
population['Year'] = years
population
# Out:
#     Population  Year
# 0   2557628654  1950
# 1   2594939877  1951
# 2   2636772306  1952
# 3   2682053389  1953
# 4   2730228104  1954
# 5   2782098943  1955
# 6   2835299673  1956
# 7   2891349717  1957
# 8   2948137248  1958
# 9   3000716593  1959
# 10  3043001508  1960
# 11  3083966929  1961
# 12  3140093217  1962
# 13  3209827882  1963
# 14  3281201306  1964
# 15  3350425793  1965
# 16  3420677923  1966
# 17  3490333715  1967
# 18  3562313822  1968
# 19  3637159050  1969
# 20  3712697742  1970
# 21  3790326948  1971
# 22  3866568653  1972
# 23  3942096442  1973
# 24  4016608813  1974
# 25  4089083233  1975
# 26  4160185010  1976
# 27  4232084578  1977
# 28  4304105753  1978
# 29  4379013942  1979
# ..         ...   ...
# 36  4940571232  1986
# 37  5027200492  1987
# 38  5114557167  1988
# 39  5201440110  1989
# 40  5288955934  1990
# 41  5371585922  1991
# 42  5456136278  1992
# 43  5538268316  1993
# 44  5618682132  1994
# 45  5699202985  1995
# 46  5779440593  1996
# 47  5857972543  1997
# 48  5935213248  1998
# 49  6012074922  1999
# 50  6088571383  2000
# 51  6165219247  2001
# 52  6242016348  2002
# 53  6318590956  2003
# 54  6395699509  2004
# 55  6473044732  2005
# 56  6551263534  2006
# 57  6629913759  2007
# 58  6709049780  2008
# 59  6788214394  2009
# 60  6866332358  2010
# 61  6944055583  2011
# 62  7022349283  2012
# 63  7101027895  2013
# 64  7178722893  2014
# 65  7256490011  2015
#
# [66 rows x 2 columns]

# %% [markdown]
# Now the data are all together in a single table! It's much easier to parse this data--if you need to know what the population was in 1959, for example, you can tell from a single glance. We'll revisit this table later.

# %% [markdown]
# ## 2. Creating Tables
#
# **Question 2.1.** In the cell below, we've created 2 arrays. Using the steps above, assign `top_10_movies` to a table that has two columns called "Rating" and "Name", which hold `top_10_movie_ratings` and `top_10_movie_names` respectively.

# %%
top_10_movie_ratings = make_array(9.2, 9.2, 9., 8.9, 8.9, 8.9, 8.9, 8.9, 8.9, 8.8)
top_10_movie_names = make_array(
        'The Shawshank Redemption (1994)',
        'The Godfather (1972)',
        'The Godfather: Part II (1974)',
        'Pulp Fiction (1994)',
        "Schindler's List (1993)",
        'The Lord of the Rings: The Return of the King (2003)',
        '12 Angry Men (1957)',
        'The Dark Knight (2008)',
        'Il buono, il brutto, il cattivo (1966)',
        'The Lord of the Rings: The Fellowship of the Ring (2001)')

top_10_movies = pd.DataFrame()
top_10_movies['Ratings'] = top_10_movie_ratings
top_10_movies['Name'] = top_10_movie_names
# We've put this next line here so your table will get printed out when you
# run this cell.
top_10_movies
# Out:
#    Ratings                                               Name
# 0      9.2                    The Shawshank Redemption (1994)
# 1      9.2                               The Godfather (1972)
# 2      9.0                      The Godfather: Part II (1974)
# 3      8.9                                Pulp Fiction (1994)
# 4      8.9                            Schindler's List (1993)
# 5      8.9  The Lord of the Rings: The Return of the King ...
# 6      8.9                                12 Angry Men (1957)
# 7      8.9                             The Dark Knight (2008)
# 8      8.9             Il buono, il brutto, il cattivo (1966)
# 9      8.8  The Lord of the Rings: The Fellowship of the R...

# %% [markdown]
# #### Loading a table from a file
# In most cases, we aren't going to go through the trouble of typing in all the data manually. Instead, we can use our `Table` functions.
#
# `Table.read_table` takes one argument, a path to a data file (a string) and returns a table.  There are many formats for data files, but CSV ("comma-separated values") is the most common.
#
# **Question 2.2.** The file `imdb.csv` contains a table of information about the 250 highest-rated movies on IMDb.  Load it as a table called `imdb`.

# 244    69988     8.1                                     8½  1963    1960
# 245  1078416     8.7                           Forrest Gump  1994    1990
# 246    31003     8.1                  Le salaire de la peur  1953    1950
# 247   167076     8.2                               3 Idiots  2009    2000
# 248    91689     8.1                                Network  1976    1970
# 249   589477     8.3  Eternal Sunshine of the Spotless Mind  2004    2000
#
# [250 rows x 5 columns]

# %% [markdown]
# Notice the part about "... (240 rows omitted)."  This table is big enough that only a few of its rows are displayed, but the others are still there.  10 are shown, so there are 250 movies total.
#
# Where did `imdb.csv` come from? Take a look at [this lab's folder](./). You should see a file called `imdb.csv`.
#
# Open up the `imdb.csv` file in that folder and look at the format. What do you notice? The `.csv` filename ending says that this file is in the [CSV (comma-separated value) format](http://edoceo.com/utilitas/csv-file-format).

# %% [markdown]
# ## 4. Analyzing datasets
# With just a few table methods, we can answer some interesting questions about the IMDb dataset.
#
# If we want just the ratings of the movies, we can get an array that contains the data in that column:

# %%
imdb["Rating"]
# Out:
# 0      8.4
# 1      8.3
# 2      8.3
# 3      8.6
# 4      8.2
# 5      8.3
# 6      8.1
# 7      8.3
# 8      8.2
# 9      8.0
# 10     8.1
# 11     8.2
# 12     8.3
# 13     8.3
# 14     8.1
# 15     8.4
# 16     8.5
# 17     8.2
# 18     8.1
# 19     8.4
# 20     8.1
# 21     8.1
# 22     9.2
# 23     8.0
# 24     8.2
# 25     8.1
# 26     8.2
# 27     8.5
# 28     8.0
# 29     8.3
#       ...
# 220    8.4
# 221    8.0
# 222    8.1
# 223    8.7
# 224    8.9
# 225    8.3
# 226    8.1
# 227    8.1
# 228    8.0
# 229    8.2
# 230    8.4
# 231    8.4
# 232    8.1
# 233    8.3
# 234    8.4
# 235    8.2
# 236    8.5
# 237    8.0
# 238    8.2
# 239    8.1
# 240    8.4
# 241    8.1
# 242    8.6
# 243    8.4
# 244    8.1
# 245    8.7
# 246    8.1
# 247    8.2
# 248    8.1
# 249    8.3
# Name: Rating, dtype: float64

# %% [markdown]
# The value of that expression is an array, exactly the same kind of thing you'd get if you typed in `make_array(8.4, 8.3, 8.3, [etc])`.
#
# **Question 4.1.** Find the rating of the highest-rated movie in the dataset.
#
# *Hint:* Think back to the functions you've learned about for working with arrays of numbers.  Ask for help if you can't remember one that's useful for this.

# %%
highest_rating = max(imdb['Rating'])
highest_rating
# Out:
# 9.1999999999999993

# %%
_ = ok.grade('q4_1')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# That's not very useful, though.  You'd probably want to know the *name* of the movie whose rating you found!  To do that, we can sort the entire table by rating, which ensures that the ratings and titles will stay together. Note that calling sort creates a copy of the table and leaves the original table unsorted.

# %%
imdb.sort_values("Rating")
# Out:
#        Votes  Rating                                              Title  Year  \
# 124    91652     8.0                                              Akira  1988
# 176   124671     8.0                            Per un pugno di dollari  1964
# 93    527349     8.0                            Guardians of the Galaxy  2014
# 92     49135     8.0                   The Man Who Shot Liberty Valance  1962
# 180    39447     8.0                                        Underground  1995
# 182    28012     8.0                                        Le samouraï  1967
# 85    268480     8.0                               Beauty and the Beast  1991
# 77     42446     8.0                                          La strada  1954
# 174   862016     8.0                                       The Avengers  2012
# 191   434906     8.0                                  The King's Speech  2010
# 70     2010
# 213    1940
# 242    2000
# 3      1990
# 78     1960
# 96     1990
# 47     1990
# 245    1990
# 68     2000
# 156    1980
# 129    1990
# 189    1970
# 103    1990
# 223    1970
# 98     1950
# 81     2010
# 87     1990
# 178    2000
# 224    1990
# 76     2000
# 57     1960
# 141    2000
# 147    1990
# 105    1950
# 91     1970
# 53     1990
# 22     1970
#
# [250 rows x 5 columns]

# %% [markdown]
# Well, that actually doesn't help much, either -- we sorted the movies from lowest -> highest ratings.  To look at the highest-rated movies, sort in reverse order:

# %%
imdb.sort_values("Rating", ascending = False)
# Out:
#        Votes  Rating                                              Title  Year  \
# 22   1027398     9.2                                      The Godfather  1972
# 53   1498733     9.2                           The Shawshank Redemption  1994
# 91    692753     9.0                             The Godfather: Part II  1974
# 105   384187     8.9                                       12 Angry Men  1957
# 57    447875     8.9             Il buono, il brutto, il cattivo (1966)  1966
# 76   1473049     8.9                                    The Dark Knight  2008
# 147   761224     8.9                                   Schindler's List  1993
# 141  1074146     8.9      The Lord of the Rings: The Return of the King  2003
# 224  1166532     8.9                                       Pulp Fiction  1994
# 178  1099087     8.8  The Lord of the Rings: The Fellowship of the Ring  2001
# 87   1177098     8.8                                         Fight Club  1999
# 129  1073043     8.7                                         The Matrix  1999
# 68    967389     8.7              The Lord of the Rings: The Two Towers  2002
# 156   700283     8.7     Star Wars: Episode V - The Empire Strikes Back  1980
# 189   770011     8.7                                          Star Wars  1977
# 223   606395     8.7                    One Flew Over the Cuckoo's Nest  1975
# 81   1271949     8.7                                          Inception  2010
# 103   644556     8.7                                         Goodfellas  1990
# 98    206216     8.7                               Shichinin no samurai  1954
# 245  1078416     8.7                                       Forrest Gump  1994
# 204   358305     8.6                                    La vita è bella  1997
# 70    689541     8.6                                       Interstellar  2014
# 78    192206     8.6                            C'era una volta il West  1968
# 169   895411     8.6                                              Se7en  1995
# 47    767224     8.6                           The Silence of the Lambs  1991
# 96    656756     8.6                                 The Usual Suspects  1995
# 3     635139     8.6                                               Léon  1994
# 213   242353     8.6                              It's a Wonderful Life  1946
# 242   476501     8.6                                     Cidade de Deus  2002
# 212   121668     8.5                                       Modern Times  1936
# ..       ...     ...                                                ...   ...
# 117   718645     8.0  Pirates of the Caribbean: The Curse of the Bla...  2003
# 116    90937     8.0                                           La haine  1995
# 112    82440     8.0                                       Mou gaan dou  2002
# 111    54651     8.0                                     Salinui chueok  2003
# 77     42446     8.0                                          La strada  1954
# 108   466111     8.0       Harry Potter and the Deathly Hallows: Part 2  2011
# 85    268480     8.0                               Beauty and the Beast  1991
# 92     49135     8.0                   The Man Who Shot Liberty Valance  1962
# 134    57644     8.0                              Trois couleurs: Rouge  1994
# 144    59377     8.0                  Lagaan: Once Upon a Time in India  2001
# 56    321834     8.0                                 The Imitation Game  2014
# 154   520391     8.0                                      Jurassic Park  1993
# 32    158867     8.0                                     Before Sunrise  1995
# 196   164419     8.0                                  Dog Day Afternoon  1975
# 35     56671     8.0                                        The Killing  1956
# 193   312516     8.0                                          Prisoners  2013
# 192    72007     8.0                                          High Noon  1952
# 191   434906     8.0                                  The King's Speech  2010
# 36     87591     8.0                                           Papillon  1973
# 182    28012     8.0                                        Le samouraï  1967
# 180    39447     8.0                                        Underground  1995
# 176   124671     8.0                            Per un pugno di dollari  1964
# 174   862016     8.0                                       The Avengers  2012
# 43     43090     8.0                                Paris, Texas (1984)  1984
# 93    527349     8.0                            Guardians of the Galaxy  2014
# 168   500576     8.0                              Monsters, Inc. (2001)  2001
# 166    59578     8.0                                      The Big Sleep  1946
# 46    427099     8.0                         X-Men: Days of Future Past  2014
# 51     87437     8.0                                      Roman Holiday  1953
# 125    26012     8.0                                        Kumonosu-jô  1957
#
#      Decade
# 22     1970
# 53     1990
# 91     1970
# 105    1950
# 57     1960
# 76     2000
# 147    1990
# 141    2000
# 224    1990
# 178    2000
# 87     1990
# 129    1990
# 68     2000
# 156    1980
# 189    1970
# 223    1970
# 81     2010
# 103    1990
# 98     1950
# 245    1990
# 204    1990
# 70     2010
# 78     1960
# 169    1990
# 47     1990
# 96     1990
# 3      1990
# 213    1940
# 242    2000
# 212    1930
# ..      ...
# 117    2000
# 116    1990
# 112    2000
# 111    2000
# 77     1950
# 108    2010
# 85     1990
# 92     1960
# 134    1990
# 144    2000
# 56     2010
# 154    1990
# 32     1990
# 196    1970
# 35     1950
# 193    2010
# 192    1950
# 191    2010
# 36     1970
# 182    1960
# 180    1990
# 176    1960
# 174    2010
# 43     1980
# 93     2010
# 168    2000
# 166    1940
# 46     2010
# 51     1950
# 125    1950
#
# [250 rows x 5 columns]

# %% [markdown]
# (The `descending=True` bit is called an *optional argument*. It has a default value of `False`, so when you explicitly tell the function `descending=True`, then the function will sort in descending order.)
#
# So there are actually 2 highest-rated movies in the dataset: *The Shawshank Redemption* and *The Godfather*.
#
# Some details about sort:
#
# 1. The first argument to `sort` is the name of a column to sort by.
# 2. If the column has strings in it, `sort` will sort alphabetically; if the column has numbers, it will sort numerically.
# 3. The value of `imdb.sort("Rating")` is a *copy of `imdb`*; the `imdb` table doesn't get modified. For example, if we called `imdb.sort("Rating")`, then running `imdb` by itself would still return the unsorted table.
# 4. Rows always stick together when a table is sorted.  It wouldn't make sense to sort just one column and leave the other columns alone.  For example, in this case, if we sorted just the "Rating" column, the movies would all end up with the wrong ratings.
#
# **Question 4.2.** Create a version of `imdb` that's sorted chronologically, with the earliest movies first.  Call it `imdb_by_year`.

# %%
imdb_by_year = imdb.sort_values('Year').reset_index().drop('index', axis = 1)
imdb_by_year
# Out:
#        Votes  Rating                                         Title  Year  \
# 0      55784     8.3                                       The Kid  1921
# 1      58506     8.2                                 The Gold Rush  1925
# 2      46332     8.2                                   The General  1926
# 3      98794     8.3                                    Metropolis  1927
# 4      88355     8.4                                             M  1931
# 5      92375     8.5                                   City Lights  1931
# 6      56842     8.1                         It Happened One Night  1934
# 7     121668     8.5                                  Modern Times  1936
# 8     259235     8.1                              The Wizard of Oz  1939
# 9     192791     8.1                            Gone with the Wind  1939
# 10     69510     8.2                  Mr. Smith Goes to Washington  1939
# 11     55793     8.1                           The Grapes of Wrath  1940
# 12     78216     8.2                                       Rebecca  1940
# 246    2010
# 247    2010
# 248    2010
# 249    2010
#
# [250 rows x 5 columns]

# %% [markdown]
# **Question 4.3.** What's the title of the earliest movie in the dataset?  You could just look this up from the output of the previous cell.  Instead, write Python code to find out.
#
# *Hint:* Starting with `imdb_by_year`, extract the Title column to get an array, then use `item` to get its first item.

# %%
earliest_movie_title = imdb_by_year['Title'][0]
earliest_movie_title
# Out:
# 'The Kid'

# %%
_ = ok.grade('q4_3')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# ## 5. Finding pieces of a dataset
# Suppose you're interested in movies from the 1940s.  Sorting the table by year doesn't help you, because the 1940s are in the middle of the dataset.
#
# Instead, we use the table method `where`.

# %%
forties = imdb[imdb['Decade'] == 1940]
forties
# Out:
#       Votes  Rating                             Title  Year  Decade
# 21    55793     8.1               The Grapes of Wrath  1940    1940
# 50    86715     8.3                  Double Indemnity  1944    1940
# 72   101754     8.1                The Maltese Falcon  1941    1940
# 75    71003     8.3  The Treasure of the Sierra Madre  1948    1940
# 102   35983     8.1       The Best Years of Our Lives  1946    1940
# 118   81887     8.3               Ladri di biciclette  1948    1940
# 120   66622     8.0                         Notorious  1946    1940
# 158  350551     8.5                        Casablanca  1942    1940
# 166   59578     8.0                     The Big Sleep  1946    1940
# 167   78216     8.2                           Rebecca  1940    1940
# 213  242353     8.6             It's a Wonderful Life  1946    1940
# 215  101785     8.3                     The Third Man  1949    1940
# 240  117590     8.4                The Great Dictator  1940    1940
# 243  268905     8.4                      Citizen Kane  1941    1940

# %% [markdown]
# Ignore the syntax for the moment.  Instead, try to read that line like this:
#
# > Assign the name **`forties`** to a table whose rows are the rows in the **`imdb`** table **`where`** the **`'Decade'`**s **`are` `equal` `to` `1940`**.
#
# **Question 5.1.** Compute the average rating of movies from the 1940s.
#
# *Hint:* The function `np.average` computes the average of an array of numbers.

# %%
average_rating_in_forties = np.average(forties['Rating'])
average_rating_in_forties
# Out:
# 8.2571428571428562

# %%
_ = ok.grade('q5_1')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# Now let's dive into the details a bit more.  `where` takes 2 arguments:
#
# 1. The name of a column.  `where` finds rows where that column's values meet some criterion.
# 2. Something that describes the criterion that the column needs to meet, called a predicate.
#
# To create our predicate, we called the function `are.equal_to` with the value we wanted, 1940.  We'll see other predicates soon.
#
# `where` returns a table that's a copy of the original table, but with only the rows that meet the given predicate.
#
# **Question 5.2.** Create a table called `ninety_nine` containing the movies that came out in the year 1999.  Use `where`.

# %%
ninety_nine = imdb[imdb['Year'] == 1999]
ninety_nine
# Out:
#        Votes  Rating            Title  Year  Decade
# 87   1177098     8.8       Fight Club  1999    1990
# 104   735056     8.4  American Beauty  1999    1990
# 115   630994     8.1  The Sixth Sense  1999    1990
# 129  1073043     8.7       The Matrix  1999    1990
# 149   672878     8.5   The Green Mile  1999    1990

# %% [markdown]
# So far we've only been finding where a column is *exactly* equal to a certain value. However, there are many other predicates.  Here are a few:
#
# |Predicate|Example|Result|
# |-|-|-|
# |`are.equal_to`|`are.equal_to(50)`|Find rows with values equal to 50|
# |`are.not_equal_to`|`are.not_equal_to(50)`|Find rows with values not equal to 50|
# |`are.above`|`are.above(50)`|Find rows with values above (and not equal to) 50|
# |`are.above_or_equal_to`|`are.above_or_equal_to(50)`|Find rows with values above 50 or equal to 50|
# |`are.below`|`are.below(50)`|Find rows with values below 50|
# |`are.between`|`are.between(2, 10)`|Find rows with values above or equal to 2 and below 10|
#
# The textbook section on selecting rows has more examples.

# %% [markdown]
# **Question 5.3.** Using `where` and one of the predicates from the table above, find all the movies with a rating higher than 8.5.  Put their data in a table called `really_highly_rated`.

# %%
really_highly_rated = imdb[imdb['Rating'] > 8.5]
really_highly_rated
# Out:
#        Votes  Rating                                              Title  Year  \
# 3     635139     8.6                                               Léon  1994
# 22   1027398     9.2                                      The Godfather  1972
# 47    767224     8.6                           The Silence of the Lambs  1991
# 53   1498733     9.2                           The Shawshank Redemption  1994
# 57    447875     8.9             Il buono, il brutto, il cattivo (1966)  1966
# 68    967389     8.7              The Lord of the Rings: The Two Towers  2002
# 70    689541     8.6                                       Interstellar  2014
# 76   1473049     8.9                                    The Dark Knight  2008
# 78    192206     8.6                            C'era una volta il West  1968
# 81   1271949     8.7                                          Inception  2010
# 87   1177098     8.8                                         Fight Club  1999
# 91    692753     9.0                             The Godfather: Part II  1974
# 96    656756     8.6                                 The Usual Suspects  1995
# 98    206216     8.7                               Shichinin no samurai  1954
# 103   644556     8.7                                         Goodfellas  1990
# 105   384187     8.9                                       12 Angry Men  1957
# 129  1073043     8.7                                         The Matrix  1999
# 141  1074146     8.9      The Lord of the Rings: The Return of the King  2003
# 147   761224     8.9                                   Schindler's List  1993
# 156   700283     8.7     Star Wars: Episode V - The Empire Strikes Back  1980
# 169   895411     8.6                                              Se7en  1995
# 178  1099087     8.8  The Lord of the Rings: The Fellowship of the Ring  2001
# 189   770011     8.7                                          Star Wars  1977
# 204   358305     8.6                                    La vita è bella  1997
# 213   242353     8.6                              It's a Wonderful Life  1946
# 223   606395     8.7                    One Flew Over the Cuckoo's Nest  1975
# 224  1166532     8.9                                       Pulp Fiction  1994
# 242   476501     8.6                                     Cidade de Deus  2002
# 245  1078416     8.7                                       Forrest Gump  1994
#
#      Decade
# 3      1990
# 22     1970
# 47     1990
# 53     1990
# 57     1960
# 68     2000
# 70     2010
# 76     2000
# 78     1960
# 81     2010
# 87     1990
# 91     1970
# 96     1990
# 98     1950
# 103    1990
# 105    1950
# 129    1990
# 141    2000
# 147    1990
# 156    1980
# 169    1990
# 178    2000
# 189    1970
# 204    1990
# 213    1940
# 223    1970
# 224    1990
# 242    2000
# 245    1990

# %% [markdown]
# **Question 5.4.** Find the average rating for movies released in the 20th century and the average rating for movies released in the 21st century for the movies in `imdb`.
#
# *Hint*: Think of the steps you need to do (take the average, find the ratings, find movies released in 20th/21st centuries), and try to put them in an order that makes sense.

# %%
average_20th_century_rating = np.average(imdb[imdb["Year"] < 2000].Rating)
average_21st_century_rating = np.average(imdb[imdb["Year"] >= 2000].Rating)
print("Average 20th century rating:", average_20th_century_rating)
print("Average 21st century rating:", average_21st_century_rating)
# Out:
# Average 20th century rating: 8.2783625731
# Average 21st century rating: 8.23797468354

# %%
_ = ok.grade('q5_4')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# The property `num_rows` tells you how many rows are in a table.  (A "property" is just a method that doesn't need to be called by adding parentheses.)

# %%
num_movies_in_dataset = len(imdb)
num_movies_in_dataset
# Out:
# 250

# %% [markdown]
# **Question 5.5.** Use `num_rows` (and arithmetic) to find the *proportion* of movies in the dataset that were released in the 20th century, and the proportion from the 21st century.
#
# *Hint:* The *proportion* of movies released in the 20th century is the *number* of movies released in the 20th century, divided by the *total number* of movies.

# %%
proportion_in_20th_century = len(imdb[imdb['Year'] < 2000])/num_movies_in_dataset
proportion_in_21st_century = len(imdb[imdb['Year'] >= 2000])/num_movies_in_dataset
print("Proportion in 20th century:", proportion_in_20th_century)
print("Proportion in 21st century:", proportion_in_21st_century)
# Out:
# Proportion in 20th century: 0.684
# Proportion in 21st century: 0.316

# %%
_ = ok.grade('q5_5')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# **Question 5.6.** Here's a challenge: Find the number of movies that came out in *even* years.
#
# *Hint:* The operator `%` computes the remainder when dividing by a number.  So `5 % 2` is 1 and `6 % 2` is 0.  A number is even if the remainder is 0 when you divide by 2.
#
# *Hint 2:* `%` can be used on arrays, operating elementwise like `+` or `*`.  So `make_array(5, 6, 7) % 2` is `array([1, 0, 1])`.
#
# *Hint 3:* Create a column called "Year Remainder" that's the remainder when each movie's release year is divided by 2.  Make a copy of `imdb` that includes that column.  Then use `where` to find rows where that new column is equal to 0.  Then use `num_rows` to count the number of such rows.

# %%
num_even_year_movies = len(imdb[imdb['Year'] % 2 == 0])
num_even_year_movies
# Out:
# 127

# %%
_ = ok.grade('q5_6')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# **Question 5.7.** Check out the `population` table from the introduction to this lab.  Compute the year when the world population first went above 6 billion.

# %%
year_population_crossed_6_billion = population[population.Population > 6000000000].reset_index().Year[0]
year_population_crossed_6_billion
# Out:
# 1999

# %%
_ = ok.grade('q5_7')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# ## 6. Miscellanea
# There are a few more table methods you'll need to fill out your toolbox.  The first 3 have to do with manipulating the columns in a table.
#
# The table `farmers_markets.csv` contains data on farmers' markets in the United States  (data collected [by the USDA]([dataset](https://apps.ams.usda.gov/FarmersMarketsExport/ExcelExport.aspx)).  Each row represents one such market.
#
# **Question 6.1.** Load the dataset into a table.  Call it `farmers_markets`.

# %%
farmers_markets = pd.read_csv('farmers_markets.csv')
farmers_markets
# Out:
#          FMID                                         MarketName  \
# 0     1012063    Caledonia Farmers Market Association - Danville
# 1     1011871                  Stearns Homestead Farmers' Market
# 2     1011878                                    100 Mile Market
# 3     1009364                  106 S. Main Street Farmers Market
# 4     1010691                10th Steet Community Farmers Market
# 5     1002454                               112st Madison Avenue
# 6     1011100                            12 South Farmers Market
# 7     1009845         125th Street Fresh Connect Farmers' Market
# 8     1005586                12th & Brandywine Urban Farm Market
# 9     1008071                               14&U Farmers' Market
# 10    1010284                           175th Street Greenmarket
# 11    1003877                                    17th Ave Market
# 12    1002619                         17th Street Farmers Market
# 13    1010968                 18th and Christian Farmers' Market
# 14    1009994                        18th Street Farmer's Market
# 15    1010376                         18th Street Farmers Market
# 16    1003233                   2014 Wood County Farmers' Market
# 17    1000709  20th Annual Highlands Business Partnership Far...
# 18    1012158                               21 Acres Farm Market
# 8520                                                NaN
# 8521                                                NaN
# 8522                                                NaN
# 8523                         http://www.yorkchamber.org
# 8524                http://www.gatewayfarmersmarket.com
# 8525                http://www.gatewayfarmersmarket.com
# 8526                  http://www.yorktonwmarketdays.com
# 8527                                                NaN
# 8528                        http://www.commongreens.com
# 8529                     http://www.urbangreenworks.org
# 8530                     http://www.urbangreenworks.org
# 8531  http://growinghope.net/farmers-markets/ypsilanti/
# 8532                             http://growinghope.net
# 8533                        http://siskiyoufoodbank.org
# 8534                                                NaN
# 8535                    http://www.yubacitydowntown.com
# 8536                  http://www.yucaipamarketnight.com
# 8537  http://www.dakotaflavor.com/category.asp?catid=12
# 8538                                                NaN
# 8539                                                NaN
# 8540                                                NaN
# 8541                         http://www.eatfreshnm.org/
# 8542                     http://www.pzfarmersmarket.org
# 8543                         http://www.zionharvest.org
# 8544             http://www.zionsvillefarmersmarket.org
# 8545                                                NaN
#
#                                                Facebook  \
# 0     https://www.facebook.com/Danville.VT.Farmers.M...
# 1                                                   NaN
# 2       https://www.facebook.com/100MileMarket/?fref=ts
# 3                                                   NaN
# 4                                                   NaN
# 5                                                   NaN
# 6                               12_South_Farmers_Market
# 7     https://www.facebook.com/125thStreetFarmersMarket
# 8     https://www.facebook.com/pages/12th-Brandywine...
# 9             https://www.facebook.com/14UFarmersMarket
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14    https://www.facebook.com/ScottsbluffFarmersMarket
# 15     https://www.facebook.com/groups/631614906915563/
# 16    https://www.facebook.com/groups/Woodcountyfarm...
# 17    https://www.facebook.com/pages/Highlands-Busin...
# 18                    https://www.facebook.com/21Acres/
# 19                                                  NaN
# 20                                                  NaN
# 21      25th Street Market - North Logan at the Library
# 22                                                  NaN
# 23                                                  NaN
# 24                              second stage of AMherst
# 25            https://www.facebook.com/2ndStreetMarket/
# 26    https://www.facebook.com/pages/3-French-Hens-F...
# 27     https://www.facebook.com/30aFarmersMarket?ref=hl
# 28    https://www.facebook.com/pages/Baltimores-32nd...
# 29                                                  NaN
# ...                                                 ...
# 8516         https://www.facebook.com/YLNIFarmersMarket
# 8517  https://www.facebook.com/pages/YMCA-Farmers-Ma...
# 8518                                                NaN
# 8519           https://www.facebook.com/VBFarmersMarket
# 8520                                                NaN
# 8521                                                NaN
# 8522                                                NaN
# 8523                                                NaN
# 8524  https://www.facebook.com/YorkGatewayFarmersMarket
# 8525  https://www.facebook.com/YorkGatewayFarmersMarket
# 8526        https://www.facebook.com/yorktownmarketdays
# 8527                                                NaN
# 8528                                                NaN
# 8529                                                NaN
# 8530                                                NaN
# 8531      https://facebook.com/YpsilantiFarmersMarkets/
# 8532      https://facebook.com/YpsilantiFarmersMarkets/
# 8533                                                NaN
# 8534       www.facebook.com/#!/yubasutter.farmersmarket
# 8535                https://www.facebook.com/ycdowntown
# 8536                                                NaN
# 8537                                                NaN
# 8538                                                NaN
# 8539                                                NaN
# 8540                                                NaN
# 8541   https://www.facebook.com/farmersmarketsnm?ref=hl
# 8542                  princeton-zimerman farmers market
# 8543  https://www.facebook.com/ZionCanyonFarmersMark...
# 8544                                                NaN
# 8545                                                NaN
#
#                                     Twitter                  Youtube  \
# 0                                       NaN                      NaN
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                                       NaN                      NaN
# 4                                       NaN                      NaN
# 5                                       NaN                      NaN
# 6                           @12southfrmsmkt                      NaN
# 7       https://twitter.com/FarmMarket125th                      NaN
# 8                                       NaN                      NaN
# 9         https://twitter.com/14UFarmersMkt                      NaN
# 10                                      NaN                      NaN
# 11                                      NaN                      NaN
# 12                                      NaN                      NaN
# 13                                      NaN                      NaN
# 14                                      NaN                      NaN
# 15                                      NaN                      NaN
# 16                                      NaN                      NaN
# 17                                      NaN                      NaN
# 18                                 @21acres  21AcresCenter's channel
# 19                                      NaN                      NaN
# 20                                      NaN                      NaN
# 21                                      NaN                      NaN
# 22                                      NaN                      NaN
# 23                                      NaN                      NaN
# 24                                      NaN                      NaN
# 25                                      NaN                      NaN
# 26                                      NaN                      NaN
# 27                                      NaN                      NaN
# 28                                      NaN                      NaN
# 29                                      NaN                      NaN
# ...                                     ...                      ...
# 8516  https://twitter.com/YLNIFarmersMarket                      NaN
# 8517                                    NaN                      NaN
# 8518                                    NaN                      NaN
# 8519                                    NaN                      NaN
# 8520                                    NaN                      NaN
# 8521                                    NaN                      NaN
# 8522                                    NaN                      NaN
# 8523                                    NaN                      NaN
# 8524                                    NaN                      NaN
# 8525                                    NaN                      NaN
# 8526                                    NaN                      NaN
# 8527                                    NaN                      NaN
# 8528                                    NaN                      NaN
# 8529                                    NaN                      NaN
# 8530                                    NaN                      NaN
# 8531                                    NaN                      NaN
# 8532                                    NaN                      NaN
# 8533                                    NaN                      NaN
# 8534                                    NaN                      NaN
# 8535                                    NaN                      NaN
# 8536                                    NaN                      NaN
# 8537                                    NaN                      NaN
# 8538                                    NaN                      NaN
# 8539                                    NaN                      NaN
# 8540                                    NaN                      NaN
# 8541                                    NaN                      NaN
# 8542                                    NaN                      NaN
# 8543                                    NaN                      NaN
# 8544                                    NaN                      NaN
# 8545                                    NaN                      NaN
#
#                                              OtherMedia  \
# 0                                                   NaN
# 1                                                   NaN
# 2              https://www.instagram.com/100milemarket/
# 3                                                   NaN
# 4     http://agrimissouri.com/mo-grown/grodetail.php...
# 5                                                   NaN
# 6                                       @12southfrmsmkt
# 7                 Instagram--> 125thStreetFarmersMarket
# 8     https://www.facebook.com/delawareurbanfarmcoal...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                                   Instagram @21acres
# 19                                                  NaN
# 20                                                  NaN
# 21    Instagram: north logan market  (25th Street Ma...
# 22                                                  NaN
# 23                                                  NaN
# 24                                                  NaN
# 25                                                  NaN
# 26                                                  NaN
# 27                                                  NaN
# 28                                                  NaN
# 29                                                  NaN
# ...                                                 ...
# 8516             https://instagram.com/YLNIFamersMarket
# 8517                                                NaN
# 8518                                                NaN
# 8519                                                NaN
# 8520                                                NaN
# 8521                                                NaN
# 8522                                                NaN
# 8523                                                NaN
# 8524                                                NaN
# 8525                                                NaN
# 8526                                                NaN
# 8527                                                NaN
# 8528                                                NaN
# 8529                                                NaN
# 8530                                                NaN
# 8531                                                NaN
# 8532                                                NaN
# 8533                                                NaN
# 8534                                                NaN
# 8535                                                NaN
# 8536                                                NaN
# 8537                                                NaN
# 8538                                                NaN
# 8539                                                NaN
# 8540                                                NaN
# 8541                                                NaN
# 8542                                                NaN
# 8543                                                NaN
# 8544                                                NaN
# 8545                                                NaN
#
#                                                  street                  city  \
# 0                                                   NaN             Danville
# 1                                       6975 Ridge Road                Parma
# 2                                       507 Harrison St             Kalamazoo
# 3                                    106 S. Main Street              Six Mile
# 4                                10th Street and Poplar                Lamar
# 5                                  112th Madison Avenue              New York
# 6                                3000 Granny White Pike             Nashville
# 7     163 West 125th Street and Adam Clayton Powell,...              New York
# 8                             12th & Brandywine Streets            Wilmington
# 9                                     1400 U Street NW             Washington
# 10                        175th Street at Wadsworth Ave              New York
# 11                                       1622 6th St NE           Minneapolis
# 12                                  17th & Main Streets              Richmond
# 13                     18th Street and Christian Street          Philadelphia
# 14                                    18th and Broadway           Scottsbluff
# 18                    King          ...                Y     Y      Y      Y
# 19                 Shawnee          ...                N     N      Y      Y
# 20            Philadelphia          ...                N     N      Y      N
# 21                   Cache          ...                N     N      Y      Y
# 22            Philadelphia          ...                N     N      Y      N
# 23            Philadelphia          ...                N     N      Y      N
# 24                 Amherst          ...                N     N      Y      N
# 25              Montgomery          ...                Y     Y      Y      Y
# 26                  Grundy          ...                Y     N      Y      N
# 27                  Walton          ...                Y     Y      Y      Y
# 28               Baltimore          ...                N     N      Y      N
# 29            Philadelphia          ...                N     N      Y      N
# ...                    ...          ...              ...   ...    ...    ...
# 8516                 Allen          ...                Y     Y      Y      N
# 8517                  Kent          ...                N     N      Y      N
# 8518              Buncombe          ...                Y     N      Y      Y
# 8519        Virginia Beach          ...                N     N      Y      N
# 8520                  Knox          ...                N     N      N      N
# 8521                Orange          ...                N     N      N      N
# 8522                  York          ...                N     N      N      N
# 8523                  York          ...                N     N      N      N
# 8524                  York          ...                N     N      Y      N
# 8525                  York          ...                N     N      Y      N
# 8526                  York          ...                Y     N      Y      Y
# 8527                Benton          ...                N     N      N      N
# 8528                  Napa          ...                N     N      N      N
# 8529            Miami-Dade          ...                N     N      N      N
# 8530            Miami-Dade          ...                N     N      N      N
# 8531             Washtenaw          ...                Y     N      Y      N
# 8532             Washtenaw          ...                N     N      Y      N
# 8533              Siskiyou          ...                Y     N      Y      N
# 8534                Sutter          ...                N     N      N      N
# 8535                Sutter          ...                N     N      Y      N
# 8536        San Bernardino          ...                N     N      N      N
# 8537                 Meade          ...                N     N      N      N
# 8538             Muskingum          ...                N     N      N      N
# 8539                Ottawa          ...                N     N      N      N
# 8540            Montgomery          ...                N     N      N      N
# 8541              Sandoval          ...                N     Y      Y      N
# 8542             Sherburne          ...                N     N      Y      N
# 8543            Washington          ...                Y     N      Y      Y
# 8544                 Boone          ...                N     N      N      N
# 8545                Platte          ...                N     N      Y      N
#
#      Juices Mushrooms PetFood Tofu WildHarvested             updateTime
# 0         Y         N       Y    N             N  6/28/2016 12:10:09 PM
# 1         N         N       Y    N             N    4/9/2016 8:05:17 PM
# 2         N         N       N    N             N  4/16/2016 12:37:56 PM
# 3         N         N       N    N             N                   2013
# 4         N         N       N    N             N  10/28/2014 9:49:46 AM
# 5         N         N       N    N             N   3/1/2012 10:38:22 AM
# 6         Y         Y       Y    N             N   5/1/2015 10:40:56 AM
# 7         Y         N       N    N             N    4/7/2014 4:32:01 PM
# 8         N         N       N    N             N    4/3/2014 3:43:31 PM
# 9         Y         N       N    N             N    4/5/2014 1:49:04 PM
# 10        N         N       N    N             N   6/3/2014 12:38:54 PM
# 11        N         N       N    N             N   4/28/2011 2:33:54 PM
# 12        N         N       N    N             N                   2009
# 13        N         N       N    N             N   3/24/2015 3:33:48 PM
# 14        N         N       N    N             N   6/29/2016 4:32:46 PM
# 15        N         N       N    N             N   6/27/2016 9:31:27 PM
# 16        Y         N       N    N             N   3/31/2014 4:57:41 PM
# 17        N         N       N    N             N   4/9/2014 10:45:36 AM
# 18        Y         Y       N    N             N   6/30/2016 7:50:56 PM
# 19        N         N       N    N             N   3/2/2015 10:46:33 AM
# 20        N         N       N    N             N   3/24/2015 2:29:42 PM
# 21        N         Y       N    N             N  4/18/2016 10:33:41 AM
# 22        N         N       N    N             N   3/24/2015 3:17:20 PM
# 23        N         N       N    N             N   3/24/2015 2:47:10 PM
# 24        N         Y       Y    N             Y    3/4/2016 1:51:55 PM
# 25        Y         Y       Y    N             N   6/30/2016 2:35:22 PM
# 26        N         N       Y    N             N   4/4/2014 11:58:41 PM
# 27        Y         Y       Y    N             Y   1/16/2015 6:38:15 PM
# 28        N         N       N    N             N   3/14/2014 1:23:50 PM
# 29        N         N       N    N             N   3/24/2015 2:28:01 PM
# ...     ...       ...     ...  ...           ...                    ...
# 8516      Y         Y       Y    N             N   3/22/2015 1:01:00 PM
# 8517      N         N       N    N             N   6/24/2013 6:29:52 PM
# 8518      Y         Y       N    N             N   4/4/2016 12:04:19 PM
# 8519      N         N       N    N             N    7/6/2015 4:17:55 PM
# 8520      N         N       N    N             N                   2009
# 8521      N         N       N    N             N                   2009
# 8522      N         N       N    N             N                   2009
# 8523      N         N       N    N             N  5/10/2012 12:29:28 PM
# 8524      N         Y       Y    N             Y  4/15/2015 10:56:05 AM
# 8525      Y         N       Y    N             Y  4/15/2015 10:48:17 AM
# 8526      Y         Y       Y    N             Y  7/23/2015 10:46:29 AM
# 8527      N         N       N    N             N                   2009
# 8528      N         N       N    N             N                   2009
# 8529      N         N       N    N             N  5/22/2012 11:19:43 PM
# 8530      N         N       N    N             N  5/22/2012 11:19:43 PM
# 8531      N         N       Y    N             N   7/5/2016 12:05:38 PM
# 8532      Y         Y       Y    N             N   7/5/2016 11:55:23 AM
# 8533      N         N       N    N             N    5/3/2016 7:51:43 PM
# 8534      N         N       N    N             N    5/4/2012 7:06:54 PM
# 8535      N         Y       N    N             N   4/11/2014 6:52:31 PM
# 8536      N         N       N    N             N   1/14/2012 5:49:10 PM
# 8537      N         N       N    N             N    Apr 16 2010  7:07PM
# 8538      N         N       N    N             N    Apr 30 2010  2:44PM
# 8539      N         N       N    N             N                   2009
# 8540      N         N       N    N             N                   2009
# 8541      N         N       N    N             N    6/5/2014 2:40:25 PM
# 8542      Y         N       N    N             N   6/27/2016 3:44:36 PM
# 8543      N         N       N    N             N   3/19/2015 1:43:50 PM
# 8544      N         N       N    N             N                   2009
# 8545      N         N       N    N             N    9/4/2015 9:48:39 AM
#
# [8546 rows x 59 columns]

# %% [markdown]
# You'll notice that it has a large number of columns in it!
#
# ### `num_columns`
#
# **Question 6.2.** The table property `num_columns` (example call: `tbl.num_columns`) produces the number of columns in a table.  Use it to find the number of columns in our farmers' markets dataset.

# %%
num_farmers_markets_columns = len(farmers_markets.columns)
print("The table has", num_farmers_markets_columns, "columns in it!")
# Out:
# The table has 59 columns in it!

# %%
_ = ok.grade('q6_2')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# Most of the columns are about particular products -- whether the market sells tofu, pet food, etc.  If we're not interested in that stuff, it just makes the table difficult to read.  This comes up more than you might think.
#
# ### `select`
#
# In such situations, we can use the table method `select` to pare down the columns of a table.  It takes any number of arguments.  Each should be the name or index of a column in the table.  It returns a new table with only those columns in it.
#
# For example, the value of `imdb.select("Year", "Decade")` is a table with only the years and decades of each movie in `imdb`.
#
# **Question 6.3.** Use `select` to create a table with only the name, city, state, latitude ('y'), and longitude ('x') of each market.  Call that new table `farmers_markets_locations`.

# %%
farmers_markets_locations = farmers_markets[['MarketName','city','State','y','x']]
farmers_markets_locations
# Out:
#                                              MarketName                  city  \
# 0       Caledonia Farmers Market Association - Danville             Danville
# 1                     Stearns Homestead Farmers' Market                Parma
# 2                                       100 Mile Market             Kalamazoo
# 3                     106 S. Main Street Farmers Market              Six Mile
# 4                   10th Steet Community Farmers Market                Lamar
# 5                                  112st Madison Avenue              New York
# 6                               12 South Farmers Market             Nashville
# 7            125th Street Fresh Connect Farmers' Market              New York
# 8                   12th & Brandywine Urban Farm Market            Wilmington
# 9                                  14&U Farmers' Market            Washington
# 10                             175th Street Greenmarket              New York
# 11                                      17th Ave Market           Minneapolis
# 12                           17th Street Farmers Market              Richmond
# 13                   18th and Christian Farmers' Market          Philadelphia
# 14                          18th Street Farmer's Market           Scottsbluff
# 15                           18th Street Farmers Market            Charleston
# 16                     2014 Wood County Farmers' Market      Wisconsin Rapids
# 17    20th Annual Highlands Business Partnership Far...             Highlands
# 18                                 21 Acres Farm Market           Woodinville
# 19                           21st Street Farmers Market                Topeka
# 20                      22nd and Tasker Farmers' Market          Philadelphia
# 21    25th Street Market - North Logan at the Librar...           North Logan
# 22                                   26th and Allegheny          Philadelphia
# 23                     29th and Wharton Farmers' Market          Philadelphia
# 24                           2nd Street Farmers' Market               Amherst
# 25            2nd Street Market - Five Rivers MetroPark                Dayton
# 26                  3 French Hens French Country Market                Morris
# 27                                  30A Farmers' Market        Rosemary Beach
# 28                   32nd Street/Waverly Farmers Market             Baltimore
# 29                     33rd and Diamond Farmers' Market          Philadelphia
# ...                                                 ...                   ...
# 8516                            YLNI Barr Street Market            Fort Wayne
# 8517                                YMCA Farmers Market          Grand Rapids
# 8518                                 YMCA Winter Market             Asheville
# 8519                      YNOT Wednesday at Town Center       Virginia Beach
# 8520                                   Yoder Cider Barn           Martinsburg
# 8521                        Yorba Linda - Old Towne CFM           Yorba Linda
# 8522                         York County Farmers Market             Rock Hill
# 8523                                York Farmers Market                  York
# 8524                York Gateway Summer Farmers' Market                  York
# 8525                York Gateway Winter Farmers' Market                  York
# 8526                               Yorktown Market Days              Yorktown
# 8527                  Youngville Café Farmers Market II  VanHorn/Newhall area
# 8528                          Yountville Farmers Market            Yountville
# 8529                                      Youth Stands!                 Miami
# 8530                                      Youth Stands!         Miami Gardens
# 8531              Ypsilanti Farmers Market - Depot Town             Ypsilanti
# 8532                Ypsilanti Farmers Market - Downtown             Ypsilanti
# 8533           Yreka Community Certified Farmers Market                Yreka
# 8534        Yuba City Certified Farmers Market-Saturday             Yuab City
# 8535        Yuba City Downtown Certified Farmers Market             Yuba City
# 8536                                        Yucaipa CFM               Yucaipa
# 8537                          Z''s Touch Farmers Market            Black Hawk
# 8538                          Zanesville Farmers Market            Zanesville
# 8539                          Zeeland Main Place Market               Zeeland
# 8540                   Zerns Farmers Market and Auction         Gilbertsville
# 8541                     Zia Bernalillo Farmers' Market            Bernalillo
# 8542                           Zimmerman Farmers Market             Zimmerman
# 8543                         Zion Canyon Farmers Market            Springdale
# 8544                          Zionsville Farmers Market            Zionsville
# 8545                          Zona Rosa Farmers' Market           Kansas City
#
#                      State          y           x
# 0                  Vermont  44.411013  -72.140305
# 1                     Ohio  41.375118  -81.728597
# 2                 Michigan  42.296024  -85.574887
# 3           South Carolina  34.804200  -82.818700
# 4                 Missouri  37.495628  -94.274619
# 5                 New York  40.793900  -73.949300
# 6                Tennessee  36.118370  -86.790709
# 7                 New York  40.808953  -73.948248
# 8                 Delaware  39.742117  -75.534460
# 9     District of Columbia  38.916998  -77.032050
# 10                New York  40.845958  -73.937802
# 11               Minnesota  45.004400  -93.259100
# 12                Virginia  37.558300  -77.488600
# 13            Pennsylvania  39.940943  -75.173431
# 14                Nebraska  41.864268 -103.662538
# 15                Illinois  39.490737  -88.163254
# 16               Wisconsin  44.394819  -89.831575
# 17              New Jersey  40.404837  -73.994358
# 18              Washington  47.750240 -122.156987
# 19                  Kansas  39.028184  -95.714514
# 20            Pennsylvania  39.932257  -75.181286
# 21                    Utah  41.778244 -111.820605
# 22            Pennsylvania  40.004095  -75.172288
# 23            Pennsylvania  39.937300  -75.192040
# 24                Virginia  37.583311  -79.048573
# 25                    Ohio  39.762593  -84.181030
# 26                Illinois  41.356383  -88.425186
# 27                 Florida  30.279017  -86.002754
# 28                Maryland  39.327200  -76.611000
# 29            Pennsylvania  39.988802  -75.187167
# ...                    ...        ...         ...
# 8516               Indiana  41.079151  -85.136171
# 8517              Michigan  42.967077  -85.680506
# 8518        North Carolina  35.624789  -82.553033
# 8519              Virginia  36.842243  -76.135642
# 8520                  Ohio  40.276000  -82.361700
# 8521            California  32.720600 -117.042000
# 8522        South Carolina  34.927600  -81.027000
# 8523              Nebraska  40.871229  -97.595572
# 8524                 Maine  43.153800  -70.658500
# 8525                 Maine  43.154172  -70.658729
# 8526              Virginia  37.238099  -76.508216
# 8527                  Iowa  41.963800  -92.027600
# 8528            California  38.402900 -122.363000
# 8529               Florida  25.850246  -80.209281
# 8530               Florida  25.918423  -80.235390
# 8531              Michigan  42.246295  -83.610492
# 8532              Michigan  42.240217  -83.615002
# 8533            California  41.712825 -122.642124
# 8534            California  39.133181 -121.613835
# 8535            California  39.138392 -121.616935
# 8536            California  34.033900 -117.039000
# 8537          South Dakota  44.174200 -103.328000
# 8538                  Ohio  39.923900  -82.023000
# 8539              Michigan  42.812300  -86.016500
# 8540          Pennsylvania  40.321600  -75.618400
# 8541            New Mexico  35.313704 -106.546840
# 8542             Minnesota  45.437700  -93.585014
# 8543                  Utah  37.184508 -113.003311
# 8544               Indiana  39.949100  -86.261200
# 8545              Missouri  39.246317  -94.580864
#
# [8546 rows x 5 columns]

# %% [markdown]
# ### `select` is not `column`!
#
# The method `select` is **definitely not** the same as the method `column`.
#
# `farmers_markets.column('y')` is an *array* of the latitudes of all the markets.  `farmers_markets.select('y')` is a table that happens to contain only 1 column, the latitudes of all the markets.
#
# **Question 6.4.** Below, we tried using the function `np.average` to find the average latitude ('y') and average longitude ('x') of the farmers' markets in the table, but we screwed something up.  Run the cell to see the (somewhat inscrutable) error message that results from calling `np.average` on a table.  Then, fix our code.

# %%
average_latitude = np.average(farmers_markets.y)
average_longitude = np.average(farmers_markets.x)
print("The average of US farmers' markets' coordinates is located at (", average_latitude, ",", average_longitude, ")")
# Out:
# The average of US farmers' markets' coordinates is located at ( 39.1864645235 , -90.9925808129 )

# %%
_ = ok.grade('q6_4')
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Running tests
#
# ---------------------------------------------------------------------
# Test summary
#     Passed: 1
#     Failed: 0
# [ooooooooook] 100.0% passed

# %% [markdown]
# ### `drop`
#
# `drop` serves the same purpose as `select`, but it takes away the columns you list instead of the ones you don't list, leaving all the rest of the columns.
#
# **Question 6.5.** Suppose you just didn't want the "FMID" or "updateTime" columns in `farmers_markets`.  Create a table that's a copy of `farmers_markets` but doesn't include those columns.  Call that table `farmers_markets_without_fmid`.

# %%
farmers_markets_without_fmid = farmers_markets.drop(["FMID","updateTime"], axis = 1)
farmers_markets_without_fmid
# Out:
#                                              MarketName  \
# 0       Caledonia Farmers Market Association - Danville
# 1                     Stearns Homestead Farmers' Market
# 2                                       100 Mile Market
# 3                     106 S. Main Street Farmers Market
# 4                   10th Steet Community Farmers Market
# 5                                  112st Madison Avenue
# 6                               12 South Farmers Market
# 7            125th Street Fresh Connect Farmers' Market
# 8                   12th & Brandywine Urban Farm Market
# 9                                  14&U Farmers' Market
# 10                             175th Street Greenmarket
# 11                                      17th Ave Market
# 12                           17th Street Farmers Market
# 13                   18th and Christian Farmers' Market
# 14                          18th Street Farmer's Market
# 15                           18th Street Farmers Market
# 16                     2014 Wood County Farmers' Market
# 17    20th Annual Highlands Business Partnership Far...
# 18                                 21 Acres Farm Market
# 19                           21st Street Farmers Market
# 20                      22nd and Tasker Farmers' Market
# 21    25th Street Market - North Logan at the Librar...
# 22                                   26th and Allegheny
# 23                     29th and Wharton Farmers' Market
# 24                           2nd Street Farmers' Market
# 25            2nd Street Market - Five Rivers MetroPark
# 26                  3 French Hens French Country Market
# 27                                  30A Farmers' Market
# 28                   32nd Street/Waverly Farmers Market
# 29                     33rd and Diamond Farmers' Market
# ...                                                 ...
# 8516                            YLNI Barr Street Market
# 8517                                YMCA Farmers Market
# 8518                                 YMCA Winter Market
# 8519                      YNOT Wednesday at Town Center
# 8520                                   Yoder Cider Barn
# 8521                        Yorba Linda - Old Towne CFM
# 8522                         York County Farmers Market
# 8523                                York Farmers Market
# 8524                York Gateway Summer Farmers' Market
# 8525                York Gateway Winter Farmers' Market
# 8526                               Yorktown Market Days
# 8527                  Youngville Café Farmers Market II
# 8528                          Yountville Farmers Market
# 8529                                      Youth Stands!
# 8530                                      Youth Stands!
# 8531              Ypsilanti Farmers Market - Depot Town
# 8532                Ypsilanti Farmers Market - Downtown
# 8533           Yreka Community Certified Farmers Market
# 8534        Yuba City Certified Farmers Market-Saturday
# 8535        Yuba City Downtown Certified Farmers Market
# 8536                                        Yucaipa CFM
# 8537                          Z''s Touch Farmers Market
# 8538                          Zanesville Farmers Market
# 8539                          Zeeland Main Place Market
# 8540                   Zerns Farmers Market and Auction
# 8541                     Zia Bernalillo Farmers' Market
# 8542                           Zimmerman Farmers Market
# 8543                         Zion Canyon Farmers Market
# 8544                          Zionsville Farmers Market
# 8545                          Zona Rosa Farmers' Market
#
#                                                 Website  \
# 0     https://sites.google.com/site/caledoniafarmers...
#
# 8520                                                NaN
# 8521                                                NaN
# 8522                                                NaN
# 8523                                                NaN
# 8524  https://www.facebook.com/YorkGatewayFarmersMarket
# 8525  https://www.facebook.com/YorkGatewayFarmersMarket
# 8526        https://www.facebook.com/yorktownmarketdays
# 8527                                                NaN
# 8528                                                NaN
# 8529                                                NaN
# 8530                                                NaN
# 8531      https://facebook.com/YpsilantiFarmersMarkets/
# 8532      https://facebook.com/YpsilantiFarmersMarkets/
# 8533                                                NaN
# 8534       www.facebook.com/#!/yubasutter.farmersmarket
# 8535                https://www.facebook.com/ycdowntown
# 8536                                                NaN
# 8537                                                NaN
# 8538                                                NaN
# 8539                                                NaN
# 8540                                                NaN
# 8541   https://www.facebook.com/farmersmarketsnm?ref=hl
# 8542                  princeton-zimerman farmers market
# 8543  https://www.facebook.com/ZionCanyonFarmersMark...
# 8544                                                NaN
# 8545                                                NaN
#
#                                     Twitter                  Youtube  \
# 0                                       NaN                      NaN
# 1                                       NaN                      NaN
# 2                                       NaN                      NaN
# 3                                       NaN                      NaN
# 4                                       NaN                      NaN
# 5                                       NaN                      NaN
# 6                           @12southfrmsmkt                      NaN
# 7       https://twitter.com/FarmMarket125th                      NaN
# 8                                       NaN                      NaN
# 9         https://twitter.com/14UFarmersMkt                      NaN
# 10                                      NaN                      NaN
# 11                                      NaN                      NaN
# 12                                      NaN                      NaN
# 13                                      NaN                      NaN
# 14                                      NaN                      NaN
# 15                                      NaN                      NaN
# 16                                      NaN                      NaN
# 17                                      NaN                      NaN
# 18                                 @21acres  21AcresCenter's channel
# 19                                      NaN                      NaN
# 20                                      NaN                      NaN
# 21                                      NaN                      NaN
# 22                                      NaN                      NaN
# 23                                      NaN                      NaN
# 24                                      NaN                      NaN
# 25                                      NaN                      NaN
# 26                                      NaN                      NaN
# 27                                      NaN                      NaN
# 28                                      NaN                      NaN
# 29                                      NaN                      NaN
# ...                                     ...                      ...
# 8516  https://twitter.com/YLNIFarmersMarket                      NaN
# 8517                                    NaN                      NaN
# 8518                                    NaN                      NaN
# 8519                                    NaN                      NaN
# 8520                                    NaN                      NaN
# 8521                                    NaN                      NaN
# 8522                                    NaN                      NaN
# 8523                                    NaN                      NaN
# 8524                                    NaN                      NaN
# 8525                                    NaN                      NaN
# 8526                                    NaN                      NaN
# 8527                                    NaN                      NaN
# 8528                                    NaN                      NaN
# 8529                                    NaN                      NaN
# 8530                                    NaN                      NaN
# 8531                                    NaN                      NaN
# 8532                                    NaN                      NaN
# 8533                                    NaN                      NaN
# 8534                                    NaN                      NaN
# 8535                                    NaN                      NaN
# 8536                                    NaN                      NaN
# 8537                                    NaN                      NaN
# 8538                                    NaN                      NaN
# 8539                                    NaN                      NaN
# 8540                                    NaN                      NaN
# 8541                                    NaN                      NaN
# 8542                                    NaN                      NaN
# 8543                                    NaN                      NaN
# 8544                                    NaN                      NaN
# 8545                                    NaN                      NaN
#
#                                              OtherMedia  \
# 0                                                   NaN
# 1                                                   NaN
# 2              https://www.instagram.com/100milemarket/
# 3                                                   NaN
# 4     http://agrimissouri.com/mo-grown/grodetail.php...
# 5                                                   NaN
# 6                                       @12southfrmsmkt
# 7                 Instagram--> 125thStreetFarmersMarket
# 8     https://www.facebook.com/delawareurbanfarmcoal...
# 9                                                   NaN
# 10                                                  NaN
# 11                                                  NaN
# 12                                                  NaN
# 13                                                  NaN
# 14                                                  NaN
# 15                                                  NaN
# 16                                                  NaN
# 17                                                  NaN
# 18                
# 8534    Town Square On Plumas St. Between B St. & C St.             Yuab City
# 8535                                  732 Plumas Street             Yuba City
# 8536                  California Street & Yucaipa Blvd.               Yucaipa
# 8537                                        Kimberly Dr            Black Hawk
# 8538                       Muskingum County Fairgrounds            Zanesville
# 8539     Heritage Square, Corner of Elm St. & Main Ave.               Zeeland
# 8540                           1100 E. Philadelphia Ave         Gilbertsville
# 8541                           335 S. Camino del Pueblo            Bernalillo
# 8542                           Lions Park, Main Street              Zimmerman
# 8543                               1212 Zion Park Blvd.            Springdale
# 8544                            Hawthorne & Main Street            Zionsville
# 8545                         Off of I-29 and Barry Road           Kansas City
#
#                     County                 State      ...       Wine Coffee  \
# 0                Caledonia               Vermont      ...          N      Y
# 1                 Cuyahoga                  Ohio      ...          N      N
# 2                Kalamazoo              Michigan      ...          Y      N
# 3                      NaN        South Carolina      ...          N      N
# 4                   Barton              Missouri      ...          N      N
# 5                 New York              New York      ...          N      N
# 6                 Davidson             Tennessee      ...          N      Y
# 7                 New York              New York      ...          Y      Y
# 8               New Castle              Delaware      ...          N      N
# 9     District of Columbia  District of Columbia      ...          N      N
# 10                New York              New York      ...          N      N
# 11                Hennepin             Minnesota      ...          N      N
# 12                 Henrico              Virginia      ...          N      N
# 13            Philadelphia          Pennsylvania      ...          N      N
# 14            Scotts Bluff              Nebraska      ...          N      Y
# 15                   Coles              Illinois      ...          N      N
# 16                    Wood             Wisconsin      ...          N      N
# 17                Monmouth            New Jersey      ...          N      N
# 18                    King            Washington      ...          N      Y
# 19                 Shawnee                Kansas      ...          N      N
# 20            Philadelphia          Pennsylvania      ...          N      N
# 21                   Cache                  Utah      ...          N      N
# 22            Philadelphia          Pennsylvania      ...          N      N
# 23            Philadelphia          Pennsylvania      ...          N      N
# 24                 Amherst              Virginia      ...          Y      N
# 25              Montgomery                  Ohio      ...          Y      Y
# 26                  Grundy              Illinois      ...          N      Y
# 27                  Walton               Florida      ...          N      Y
# 28               Baltimore              Maryland      ...          N      N
# 29            Philadelphia          Pennsylvania      ...          N      N
# ...                    ...                   ...      ...        ...    ...
# 8516                 Allen               Indiana      ...          N      Y
# 8517                  Kent              Michigan      ...          N      N
# 8518              Buncombe        North Carolina      ...          N      Y
# 8519        Virginia Beach              Virginia      ...          N      N
# 8520                  Knox                  Ohio      ...          N      N
# 8521                Orange            California      ...          N      N
# 8522                  York        South Carolina      ...          N      N
# 8523                  York              Nebraska      ...          N      N
# 8524                  York                 Maine      ...          Y      N
# 8525                  York                 Maine      ...          N      N
# 8526                  York              Virginia      ...          N      Y
# 8527                Benton                  Iowa      ...          N      N
# 8528                  Napa            California      ...          N      N
# 8529            Miami-Dade               Florida      ...          N      N
# 8530            Miami-Dade               Florida      ...          N      N
# 8531             Washtenaw              Michigan      ...          N      Y
# 8532             Washtenaw              Michigan      ...          N      N
# 8533              Siskiyou            California      ...          N      Y
# 8534                Sutter            California      ...          N      N
# 8535                Sutter            California      ...          N      N
# 8536        San Bernardino            California      ...          N      N
# 8537                 Meade          South Dakota      ...          N      N
# 8538             Muskingum                  Ohio      ...          N      N
# 8539                Ottawa              Michigan      ...          N      N
# 8540            Montgomery          Pennsylvania      ...          N      N
# 8541              Sandoval            New Mexico      ...          N      N
# 8542             Sherburne             Minnesota      ...          N      N
# 8543            Washington                  Utah      ...          N      Y
# 8544                 Boone               Indiana      ...          N      N
# 8545                Platte              Missouri      ...          N      N
#
#      Beans Fruits Grains Juices Mushrooms PetFood Tofu  WildHarvested
# 0        Y      Y      N      Y         N       Y    N              N
# 1        N      Y      N      N         N       Y    N              N
# 2        N      Y      Y      N         N       N    N              N
# 3        N      N      N      N         N       N    N              N
# 4        N      Y      N      N         N       N    N              N
# 5        N      N      N      N         N       N    N              N
# 6        N      Y      N      Y         Y       Y    N              N
# 7        N      Y      N      Y         N       N    N              N
# 8        N      Y      N      N         N       N    N              N
# 9        Y      Y      Y      Y         N       N    N              N
# 10       N      Y      N      N         N       N    N              N
# 11       N      N      N      N         N       N    N              N
# 12       N      N      N      N         N       N    N              N
# 13       N      Y      N      N         N       N    N              N
# 14       Y      Y      N      N         N       N    N              N
# 15       N      Y      N      N         N       N    N              N
# 16       N      Y      N      Y         N       N    N              N
# 17       N      Y      N      N         N       N    N              N
# 18       Y      Y      Y      Y         Y       N    N              N
# 19       N      Y      Y      N         N       N    N              N
# 20       N      Y      N      N         N       N    N              N
# 21       N      Y      Y      N         Y       N    N              N
# 22       N      Y      N      N         N       N    N              N
# 23       N      Y      N      N         N       N    N              N
# 24       N      Y      N      N         Y       Y    N              Y
# 25       Y      Y      Y      Y         Y       Y    N              N
# 26       N      Y      N      N         N       Y    N              N
# 27       Y      Y      Y      Y         Y       Y    N              Y
# 28       N      Y      N      N         N       N    N              N
# 29       N      Y      N      N         N       N    N              N
# ...    ...    ...    ...    ...       ...     ...  ...            ...
# 8516     Y      Y      N      Y         Y       Y    N              N
# 8517     N      Y      N      N         N       N    N              N
# 8518     N      Y      Y      Y         Y       N    N              N
# 8519     N      Y      N      N         N       N    N              N
# 8520     N      N      N      N         N       N    N              N
# 8521     N      N      N      N         N       N    N              N
# 8522     N      N      N      N         N       N    N              N
# 8523     N      N      N      N         N       N    N              N
# 8524     N      Y      N      N         Y       Y    N              Y
# 8525     N      Y      N      Y         N       Y    N              Y
# 8526     N      Y      Y      Y         Y       Y    N              Y
# 8527     N      N      N      N         N       N    N              N
# 8528     N      N      N      N         N       N    N              N
# 8529     N      N      N      N         N       N    N              N
# 8530     N      N      N      N         N       N    N              N
# 8531     N      Y      N      N         N       Y    N              N
# 8532     N      Y      N      Y         Y       Y    N              N
# 8533     N      Y      N      N         N       N    N              N
# 8534     N      N      N      N         N       N    N              N
# 8535     N      Y      N      N         Y       N    N              N
# 8536     N      N      N      N         N       N    N              N
# 8537     N      N      N      N         N       N    N              N
# 8538     N      N      N      N         N       N    N              N
# 8539     N      N      N      N         N       N    N              N
# 8540     N      N      N      N         N       N    N              N
# 8541     Y      Y      N      N         N       N    N              N
# 8542     N      Y      N      Y         N       N    N              N
# 8543     N      Y      Y      N         N       N    N              N
# 8544     N      N      N      N         N       N    N              N
# 8545     N      Y      N      N         N       N    N              N
#
# [8546 rows x 57 columns]

# %% [markdown]
# #### `take`
# Let's find the 5 northernmost farmers' markets in the US.  You already know how to sort by latitude ('y'), but we haven't seen how to get the first 5 rows of a table.  That's what `take` is for.
#
# The table method `take` takes as its argument an array of numbers.  Each number should be the index of a row in the table.  It returns a new table with only those rows.
#
# Most often you'll want to use `take` in conjunction with `np.arange` to take the first few rows of a table.
#
# **Question 6.6.** Make a table of the 5 northernmost farmers' markets in `farmers_markets_locations`.  Call it `northern_markets`.  (It should include the same columns as `farmers_markets_locations`.

# %%
northern_markets = farmers_markets_locations.sort_values('y', ascending = False).head()
northern_markets
# Out:
#                          MarketName            city   State          y  \
# 7274   Tanana Valley Farmers Market       Fairbanks  Alaska  64.862750
# 2392         Ester Community Market           Ester  Alaska  64.845900
# 2430      Fairbanks Downtown Market       Fairbanks  Alaska  64.844414
# 5182         Nenana Open Air Market          Nenana  Alaska  64.556600
# 3496  Highway's End Farmers' Market  Delta Junction  Alaska  64.038462
#
#                x
# 7274 -147.781100
# 2392 -148.010000
# 2430 -147.719593
# 5182 -149.096000
# 3496 -145.733115

# %% [markdown]
# **Question 6.7.** Make a table of the farmers' markets in Berkeley, California.  (It should include the same columns as `farmers_markets_locations`.)

# %%
berkeley_markets = farmers_markets_locations[farmers_markets_locations.city == 'Berkeley']
berkeley_markets
# Out:
#                              MarketName      city       State          y  \
# 1938  Downtown Berkeley Farmers' Market  Berkeley  California  37.869692
# 5308     North Berkeley Farmers' Market  Berkeley  California  37.880235
# 6881     South Berkeley Farmers' Market  Berkeley  California  37.847761
#
#                x
# 1938 -122.272792
# 5308 -122.269242
# 6881 -122.271922

# %% [markdown]
# Recognize any of them?

# %% [markdown]
# ## 7. Summary
#
# For your reference, here's a table of all the functions and methods we saw in this lab.
#
# |Name|Example|Purpose|
# |-|-|-|
# |`Table`|`Table()`|Create an empty table, usually to extend with data|
# |`Table.read_table`|`Table.read_table("my_data.csv")`|Create a table from a data file|
# |`with_columns`|`tbl = Table().with_columns("N", np.arange(5), "2*N", np.arange(0, 10, 2))`|Create a copy of a table with more columns|
# |`column`|`tbl.column("N")`|Create an array containing the elements of a column|
# |`sort`|`tbl.sort("N")`|Create a copy of a table sorted by the values in a column|
# |`where`|`tbl.where("N", are.above(2))`|Create a copy of a table with only the rows that match some *predicate*|
# |`num_rows`|`tbl.num_rows`|Compute the number of rows in a table|
# |`num_columns`|`tbl.num_columns`|Compute the number of columns in a table|
# |`select`|`tbl.select("N")`|Create a copy of a table with only some of the columns|
# |`drop`|`tbl.drop("2*N")`|Create a copy of a table without some of the columns|
# |`take`|`tbl.take(np.arange(0, 6, 2))`|Create a copy of the table with only the rows whose indices are in the given array|
#
# <br/>
#
# Alright! You're finished with lab 3!  Be sure to...
# - **run all the tests** (the next cell has a shortcut for that),
# - **Save and Checkpoint** from the `File` menu,
# - **run the last cell to submit your work**,
# - and ask one of the staff members to check you off.

# %%
# For your convenience, you can run this cell to run all the tests at once!
##import os
##_ = [ok.grade(q[:-3]) for q in os.listdir("tests") if q.startswith('q')]

# %%
##_ = ok.submit()
